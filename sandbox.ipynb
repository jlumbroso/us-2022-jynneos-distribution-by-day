# %%
import bs4, waybackpy, requests, pytz, html2csv

# %%
arcapi = waybackpy.WaybackMachineCDXServerAPI(
    url="https://aspr.hhs.gov/SNS/Pages/JYNNEOS-Distribution.aspx",
    user_agent="Jynneos scraper [https://github.com/jlumbroso/us-2022-jynneos-distribution-by-day]"
)

# %%
x = arcapi.oldest()

# %%
x.archive_url
# Out:
# 'https://web.archive.org/web/20220706223613/https://aspr.hhs.gov/SNS/Pages/JYNNEOS-Distribution.aspx'

# %%
s = bs4.BeautifulSoup(requests.get(x.archive_url).content)

# %%
s.find("div", {"class": "table-responsive"}).find("table")
# Out:
# <table class="table table-bordered table-condensed table-sticky">
# <thead>
# <tr>
# <th scope="col">Jurisdiction</th>
# <th scope="col">Total Distribution</th>
# </tr>
# </thead>
# <tbody>
# <tr class="lightblue">
# <th class="lightblue" scope="row">
# <strong>All Jurisdictions (patient courses)</strong></th>
# <td class="lightblue">
# <b>41,520</b></td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Alaska</td>
# <td align="right">20</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Arizona</td>
# <td align="right">118</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">California</td>
# <td align="right">12,156</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Chicago</td>
# <td align="right">5,409</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Colorado</td>
# <td align="right">1,340</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Connecticut</td>
# <td align="right">10</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Delaware</td>
# <td align="right">16</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">District of Columbia</td>
# <td align="right">1,706</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Florida</td>
# <td align="right">503</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Georgia</td>
# <td align="right">238</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Hawaii</td>
# <td align="right">557</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Illinois</td>
# <td align="right">126</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Indiana</td>
# <td align="right">520</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Iowa</td>
# <td align="right">26</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Kentucky</td>
# <td align="right">70</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Los Angeles</td>
# <td align="right">7,346</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Louisiana</td>
# <td align="right">20</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Maine</td>
# <td align="right">40</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Maryland</td>
# <td align="right">158</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Massachusetts</td>
# <td align="right">2,204</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Michigan</td>
# <td align="right">24</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Minnesota</td>
# <td align="right">40</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Mississippi</td>
# <td align="right">10</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Missouri</td>
# <td align="right">4</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Nebraska</td>
# <td align="right">50</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Nevada</td>
# <td align="right">4</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">New    Jersey</td>
# <td align="right">300</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">New York</td>
# <td align="right">31</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">New    York City</td>
# <td align="right">7,169</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">North Carolina</td>
# <td align="right">60</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Ohio</td>
# <td align="right">4</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Oklahoma</td>
# <td align="right">36</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Oregon</td>
# <td align="right">219</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Pennsylvania</td>
# <td align="right">98</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Puerto    Rico</td>
# <td align="right">40</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Rhode Island</td>
# <td align="right">20</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">South    Carolina</td>
# <td align="right">34</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Utah</td>
# <td align="right">20</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Texas</td>
# <td align="right">166</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Virginia</td>
# <td align="right">512</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Washington</td>
# <td align="right">68</td>
# </tr>
# <tr>
# <td align="left" style="text-align: left;">Wisconsin</td>
# <td align="right">28</td>
# </tr>
# </tbody>
# </table>

# %%
import locale

STRIP_NUMERIC_CHARS = "*\u200b"

locale.setlocale(locale.LC_NUMERIC, "en_US.UTF-8")

def convert_if_numeric(s):
    try:
        return locale.atoi(s.strip(STRIP_NUMERIC_CHARS))
    except ValueError:
        return s.strip()

def make_table_numeric(list_of_lists):

    convd_list_of_lists = [
        [
            convert_if_numeric(cell)
            for cell in row
        ]
        for row in list_of_lists
    ]

    return convd_list_of_lists

# %%
singl_fields
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jlumbroso/Programming/scrapers/us-2022-jynneos-distribution-by-day/sandbox.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jlumbroso/Programming/scrapers/us-2022-jynneos-distribution-by-day/sandbox.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> singl_fields
#
# NameError: name 'singl_fields' is not defined

# %%
BASE_URL = "https://aspr.hhs.gov/SNS/Pages/JYNNEOS-Distribution.aspx"

def convert_table(list_of_list):
    [
        [ cell for cell in row ]
        for row in list_of_list
    ]

SUBSTITUTIONS = {
    'Allocation 2022-06-29 To 2022-07-08': 'Allocation 2022-06-29 to 2022-07-08',
    'Allocation 2022-07-08 To 2022-07-15': 'Allocation 2022-07-08 to 2022-07-15',
    'Allocation 2022-07-16 To 2022-07-29': 'Allocation 2022-07-16 to 2022-07-29',
    'Allocation 2022-07-29 To Onwards': 'Allocation 2022-07-29 to onwards',
    'Allocation July 29' : 'Allocation 2022-07-29 to onwards',
    'AllocationJune 28-July 27' : 'Allocation 2022-06-28 to 2022-07-27',
    'Jurisdiction': 'Jurisdiction',
    'Total    Allocation': 'Total allocation',
    'Total Allocation': 'Total allocation',
    'Total Distribution': 'Total distribution',
    'Total Distribution (Doses)\u200b': 'Total distribution',
    'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 'Total shipped as of 2022-07-27',
    'Total Requested': 'Total requested',
    'Total Requested as of July 27 at 8AM': 'Total requested as of 2022-07-27',
    'Total Requestedas of Aug 03 2022, 12pm': 'Total requested as of 2022-08-03',
    'Total Requestedas of Aug 08 2022, 12pm': 'Total requested as of 2022-08-08',
    'Total Requestedas of Aug 10 2022, 12pm': 'Total requested as of 2022-08-10',
    'Total Requestedas of Aug 12\u200b 2022, 12pm': 'Total requested as of 2022-08-12',
    'Total Shippedas of Aug 03 2022, 12pm': 'Total shipped as of 2022-08-03',
    'Total Shippedas of Aug 08 2022, 12pm': 'Total shipped as of 2022-08-08',
    'Total Shippedas of Aug 10 2022, 12pm': 'Total shipped as of 2022-08-10',
    'Total Shippedas of Aug 12 2022, 12\u200bpm': 'Total shipped as of 2022-08-12',
    'Total Shipped\xa0(Doses)\u200b': 'Total shipped',
}

def fetch_jynneos_table_near(year, month, day):
    archive = waybackpy.WaybackMachineCDXServerAPI(
        url=BASE_URL,
        user_agent="Jynneos scraper [https://github.com/jlumbroso/us-2022-jynneos-distribution-by-day]"
    )

    near = archive.near(year=year, month=month, day=day)
    
    r = requests.get(near.archive_url)
    s = bs4.BeautifulSoup(r.content)
    
    table_element = s.find("div", {"class": "table-responsive"}).find("table")

    raw_tables = Converter().convert_to_list(str(table_element))
    
    if len(raw_tables) == 0:
        return

    raw_table = raw_tables[0]
    num_table = make_table_numeric(raw_table)

    header_row = num_table[0]
    body_rows = num_table[1:]
    entries = [
        dict(zip(header_row, row))
        for row in body_rows
    ]

    # clean entries
    for entry in entries:

        # normalize the "All Jurisdiction" caption
        if "all " in entry["Jurisdiction"].lower():
            entry["Jurisdiction"] = "All"

        # substitute some key names
        for old, new in SUBSTITUTIONS.items():
            if old == new:
                continue
            if old in entry:
                entry[new] = entry[old]
                del entry[old]
    
    return entries

# %%
table_element = bs4.BeautifulSoup(requests.get("https://web.archive.org/web/20220706223613/https://aspr.hhs.gov/SNS/Pages/JYNNEOS-Distribution.aspx").content).find("div", {"class": "table-responsive"}).find("table")

# %%
make_table_numeric(Converter().convert_to_list(str(table_element))[0])
# Out:
# [['Jurisdiction', 'Total Distribution'],
#  ['All Jurisdictions (patient courses)', 41520],
#  ['Alaska', 20],
#  ['Arizona', 118],
#  ['California', 12156],
#  ['Chicago', 5409],
#  ['Colorado', 1340],
#  ['Connecticut', 10],
#  ['Delaware', 16],
#  ['District of Columbia', 1706],
#  ['Florida', 503],
#  ['Georgia', 238],
#  ['Hawaii', 557],
#  ['Illinois', 126],
#  ['Indiana', 520],
#  ['Iowa', 26],
#  ['Kentucky', 70],
#  ['Los Angeles', 7346],
#  ['Louisiana', 20],
#  ['Maine', 40],
#  ['Maryland', 158],
#  ['Massachusetts', 2204],
#  ['Michigan', 24],
#  ['Minnesota', 40],
#  ['Mississippi', 10],
#  ['Missouri', 4],
#  ['Nebraska', 50],
#  ['Nevada', 4],
#  ['New    Jersey', 300],
#  ['New York', 31],
#  ['New    York City', 7169],
#  ['North Carolina', 60],
#  ['Ohio', 4],
#  ['Oklahoma', 36],
#  ['Oregon', 219],
#  ['Pennsylvania', 98],
#  ['Puerto    Rico', 40],
#  ['Rhode Island', 20],
#  ['South    Carolina', 34],
#  ['Utah', 20],
#  ['Texas', 166],
#  ['Virginia', 512],
#  ['Washington', 68],
#  ['Wisconsin', 28]]

# %%
import script
import importlib
importlib.reload(script)
# Out:
# <module 'script' from '/Users/jlumbroso/Programming/scrapers/us-2022-jynneos-distribution-by-day/script.py'>

# %%
start = (2022, 7, 1)
year, month, day = start
prev_data = None

data = dict()


KEY = "Jurisdiction"

while not script.in_future(year, month, day):
    new_data = fetch_jynneos_table_near(year, month, day)
    
    if prev_data is None or [i for i in new_data if i not in prev_data] != []:

        for entry in new_data:

            # skip corrupt entries
            if KEY not in entry:
                continue
            
            data_key = entry[KEY]
            data[data_key] = data.get(data_key, dict())

            for key, value in entry.items():
                if key == KEY:
                    continue
                
                data[data_key]["{} ({}-{:02}-{:02})".format(key, year, month, day)] = value
            

    year, month, day = script.next_day(year, month, day)
    prev_data = new_data

# %%
data["New Jersey"]
# Out:
# {'Total distribution (2022-07-14)': 2813,
#  'Total distribution (2022-07-18)': 2813,
#  'Total allocation (2022-07-22)': 5449,
#  'Total requested (2022-07-22)': 5509,
#  'Total shipped (2022-07-22)': 5509,
#  'Total allocation (2022-07-27)': 5449,
#  'Total requested (2022-07-27)': 5509,
#  'Total shipped (2022-07-27)': 5509,
#  'Allocation 2022-07-29 to onwards (2022-07-29)': 14520,
#  'Allocation 2022-06-28 to 2022-07-27 (2022-07-29)': 5449,
#  'Total allocation (2022-07-29)': 19969,
#  'Total deployed as of 2022-07-27 (2022-07-29)': 5509,
#  'Total requested (2022-07-29)': 5509,
#  'Allocation 2022-07-29 to onwards (2022-08-02)': 14520,
#  'Allocation 2022-06-28 to 2022-07-27 (2022-08-02)': 5449,
#  'Total allocation (2022-08-02)': 19969,
#  'Total deployed as of 2022-07-27 (2022-08-02)': 5509,
#  'Total requested as of 2022-07-27 (2022-08-02)': 5509,
#  'Allocation 2022-06-29 to 2022-07-08 (2022-08-05)': 347,
#  'Allocation 2022-07-08 to 2022-07-15 (2022-08-05)': 2406,
#  'Allocation 2022-07-16 to 2022-07-29 (2022-08-05)': 2696,
#  'Allocation 2022-07-29 to onwards (2022-08-05)': 14520,
#  'Total allocation (2022-08-05)': 19969,
#  'Total requested as of 2022-08-03 (2022-08-05)': 11329,
#  'Total shipped as of 2022-08-03 (2022-08-05)': 11329,
#  'Allocation 2022-06-29 to 2022-07-08 (2022-08-09)': 347,
#  'Allocation 2022-07-08 to 2022-07-15 (2022-08-09)': 2406,
#  'Allocation 2022-07-16 to 2022-07-29 (2022-08-09)': 2696,
#  'Allocation 2022-07-29 to onwards (2022-08-09)': 14520,
#  'Total allocation (2022-08-09)': 19969,
#  'Total requested as of 2022-08-08 (2022-08-09)': 11329,
#  'Total shipped as of 2022-08-08 (2022-08-09)': 11329,
#  'Allocation 2022-06-29 to 2022-07-08 (2022-08-11)': 347,
#  'Allocation 2022-07-08 to 2022-07-15 (2022-08-11)': 2406,
#  'Allocation 2022-07-16 to 2022-07-29 (2022-08-11)': 2696,
#  'Allocation 2022-07-29 to onwards (2022-08-11)': 14520,
#  'Total allocation (2022-08-11)': 19969,
#  'Total requested as of 2022-08-10 (2022-08-11)': 11329,
#  'Total shipped as of 2022-08-10 (2022-08-11)': 11329,
#  'Allocation 2022-06-29 to 2022-07-08 (2022-08-13)': 347,
#  'Allocation 2022-07-08 to 2022-07-15 (2022-08-13)': 2406,
#  'Allocation 2022-07-16 to 2022-07-29 (2022-08-13)': 2696,
#  'Allocation 2022-07-29 to onwards (2022-08-13)': 14520,
#  'Total allocation (2022-08-13)': 19969,
#  'Total requested as of 2022-08-12 (2022-08-13)': 11329,
#  'Total shipped as of 2022-08-12 (2022-08-13)': 11329}

# %%
fetch_jynneos_table_near(2022, 7, 31)
# Out:
# [{'Jurisdiction': 'All',
#   'Allocation 2022-07-29 to onwards': 736620,
#   'Allocation 2022-06-28 to 2022-07-27': 333218,
#   'Total allocation': 1069838,
#   'Total deployed as of 2022-07-27': 336710,
#   'Total requested': 337016},
#  {'Jurisdiction': 'Alabama',
#   'Allocation 2022-07-29 to onwards': 4640,
#   'Allocation 2022-06-28 to 2022-07-27': 1283,
#   'Total allocation': 5923,
#   'Total deployed as of 2022-07-27': 1283,
#   'Total requested': 1283},
#  {'Jurisdiction': 'Alaska',
#   'Allocation 2022-07-29 to onwards': 480,
#   'Allocation 2022-06-28 to 2022-07-27': 120,
#   'Total allocation': 600,
#   'Total deployed as of 2022-07-27': 102,
#   'Total requested': 102},
#  {'Jurisdiction': 'Arizona',
#   'Allocation 2022-07-29 to onwards': 10820,
#   'Allocation 2022-06-28 to 2022-07-27': 3495,
#   'Total allocation': 14315,
#   'Total deployed as of 2022-07-27': 3613,
#   'Total requested': 3613},
#  {'Jurisdiction': 'Arkansas',
#   'Allocation 2022-07-29 to onwards': 2300,
#   'Allocation 2022-06-28 to 2022-07-27': 724,
#   'Total allocation': 3024,
#   'Total deployed as of 2022-07-27': 100,
#   'Total requested': 20},
#  {'Jurisdiction': 'California -    Los Angeles',
#   'Allocation 2022-07-29 to onwards': 48120,
#   'Allocation 2022-06-28 to 2022-07-27': 22982,
#   'Total allocation': 71102,
#   'Total deployed as of 2022-07-27': 23982,
#   'Total requested': 22982},
#  {'Jurisdiction': 'California -    Other',
#   'Allocation 2022-07-29 to onwards': 72520,
#   'Allocation 2022-06-28 to 2022-07-27': 34629,
#   'Total allocation': 107149,
#   'Total deployed as of 2022-07-27': 37289,
#   'Total requested': 38229},
#  {'Jurisdiction': 'Colorado',
#   'Allocation 2022-07-29 to onwards': 12660,
#   'Allocation 2022-06-28 to 2022-07-27': 5865,
#   'Total allocation': 18525,
#   'Total deployed as of 2022-07-27': 6205,
#   'Total requested': 6205},
#  {'Jurisdiction': 'Connecticut',
#   'Allocation 2022-07-29 to onwards': 4520,
#   'Allocation 2022-06-28 to 2022-07-27': 1778,
#   'Total allocation': 6298,
#   'Total deployed as of 2022-07-27': 1808,
#   'Total requested': 1808},
#  {'Jurisdiction': 'Delaware',
#   'Allocation 2022-07-29 to onwards': 1440,
#   'Allocation 2022-06-28 to 2022-07-27': 413,
#   'Total allocation': 1853,
#   'Total deployed as of 2022-07-27': 415,
#   'Total requested': 415},
#  {'Jurisdiction': 'District of    Columbia',
#   'Allocation 2022-07-29 to onwards': 20020,
#   'Allocation 2022-06-28 to 2022-07-27': 13255,
#   'Total allocation': 33275,
#   'Total deployed as of 2022-07-27': 13755,
#   'Total requested': 13939},
#  {'Jurisdiction': 'Florida',
#   'Allocation 2022-07-29 to onwards': 72900,
#   'Allocation 2022-06-28 to 2022-07-27': 36383,
#   'Total allocation': 109283,
#   'Total deployed as of 2022-07-27': 36800,
#   'Total requested': 36800},
#  {'Jurisdiction': 'Georgia',
#   'Allocation 2022-07-29 to onwards': 34120,
#   'Allocation 2022-06-28 to 2022-07-27': 13876,
#   'Total allocation': 47996,
#   'Total deployed as of 2022-07-27': 11505,
#   'Total requested': 11505},
#  {'Jurisdiction': 'Hawaii',
#   'Allocation 2022-07-29 to onwards': 2660,
#   'Allocation 2022-06-28 to 2022-07-27': 1584,
#   'Total allocation': 4244,
#   'Total deployed as of 2022-07-27': 1512,
#   'Total requested': 1512},
#  {'Jurisdiction': 'Idaho',
#   'Allocation 2022-07-29 to onwards': 1380,
#   'Allocation 2022-06-28 to 2022-07-27': 420,
#   'Total allocation': 1800,
#   'Total deployed as of 2022-07-27': 440,
#   'Total requested': 440},
#  {'Jurisdiction': 'Illinois -    Chicago',
#   'Allocation 2022-07-29 to onwards': 33160,
#   'Allocation 2022-06-28 to 2022-07-27': 18709,
#   'Total allocation': 51869,
#   'Total deployed as of 2022-07-27': 20849,
#   'Total requested': 20849},
#  {'Jurisdiction': 'Illinois -    Other',
#   'Allocation 2022-07-29 to onwards': 13120,
#   'Allocation 2022-06-28 to 2022-07-27': 7392,
#   'Total allocation': 20512,
#   'Total deployed as of 2022-07-27': 7458,
#   'Total requested': 7458},
#  {'Jurisdiction': 'Indiana',
#   'Allocation 2022-07-29 to onwards': 8800,
#   'Allocation 2022-06-28 to 2022-07-27': 3185,
#   'Total allocation': 11985,
#   'Total deployed as of 2022-07-27': 3232,
#   'Total requested': 3232},
#  {'Jurisdiction': 'Iowa',
#   'Allocation 2022-07-29 to onwards': 1920,
#   'Allocation 2022-06-28 to 2022-07-27': 649,
#   'Total allocation': 2569,
#   'Total deployed as of 2022-07-27': 661,
#   'Total requested': 661},
#  {'Jurisdiction': 'Kansas',
#   'Allocation 2022-07-29 to onwards': 1700,
#   'Allocation 2022-06-28 to 2022-07-27': 494,
#   'Total allocation': 2194,
#   'Total deployed as of 2022-07-27': 216,
#   'Total requested': 216},
#  {'Jurisdiction': 'Kentucky',
#   'Allocation 2022-07-29 to onwards': 4680,
#   'Allocation 2022-06-28 to 2022-07-27': 1630,
#   'Total allocation': 6310,
#   'Total deployed as of 2022-07-27': 1700,
#   'Total requested': 1700},
#  {'Jurisdiction': 'Louisiana',
#   'Allocation 2022-07-29 to onwards': 7200,
#   'Allocation 2022-06-28 to 2022-07-27': 2022,
#   'Total allocation': 9222,
#   'Total deployed as of 2022-07-27': 2082,
#   'Total requested': 2082},
#  {'Jurisdiction': 'Maine',
#   'Allocation 2022-07-29 to onwards': 1100,
#   'Allocation 2022-06-28 to 2022-07-27': 271,
#   'Total allocation': 1371,
#   'Total deployed as of 2022-07-27': 311,
#   'Total requested': 311},
#  {'Jurisdiction': 'Maryland',
#   'Allocation 2022-07-29 to onwards': 15400,
#   'Allocation 2022-06-28 to 2022-07-27': 6405,
#   'Total allocation': 21805,
#   'Total deployed as of 2022-07-27': 6519,
#   'Total requested': 6519},
#  {'Jurisdiction': 'Massachusetts',
#   'Allocation 2022-07-29 to onwards': 17040,
#   'Allocation 2022-06-28 to 2022-07-27': 9231,
#   'Total allocation': 26271,
#   'Total deployed as of 2022-07-27': 9431,
#   'Total requested': 9431},
#  {'Jurisdiction': 'Michigan',
#   'Allocation 2022-07-29 to onwards': 10460,
#   'Allocation 2022-06-28 to 2022-07-27': 3398,
#   'Total allocation': 13858,
#   'Total deployed as of 2022-07-27': 3418,
#   'Total requested': 3418},
#  {'Jurisdiction': 'Minnesota',
#   'Allocation 2022-07-29 to onwards': 7600,
#   'Allocation 2022-06-28 to 2022-07-27': 2758,
#   'Total allocation': 10358,
#   'Total deployed as of 2022-07-27': 2998,
#   'Total requested': 2998},
#  {'Jurisdiction': 'Mississippi',
#   'Allocation 2022-07-29 to onwards': 2320,
#   'Allocation 2022-06-28 to 2022-07-27': 591,
#   'Total allocation': 2911,
#   'Total deployed as of 2022-07-27': 601,
#   'Total requested': 601},
#  {'Jurisdiction': 'Missouri',
#   'Allocation 2022-07-29 to onwards': 6940,
#   'Allocation 2022-06-28 to 2022-07-27': 2427,
#   'Total allocation': 9367,
#   'Total deployed as of 2022-07-27': 2140,
#   'Total requested': 2140},
#  {'Jurisdiction': 'Montana',
#   'Allocation 2022-07-29 to onwards': 600,
#   'Allocation 2022-06-28 to 2022-07-27': 150,
#   'Total allocation': 750,
#   'Total deployed as of 2022-07-27': 98,
#   'Total requested': 98},
#  {'Jurisdiction': 'Nebraska',
#   'Allocation 2022-07-29 to onwards': 1240,
#   'Allocation 2022-06-28 to 2022-07-27': 411,
#   'Total allocation': 1651,
#   'Total deployed as of 2022-07-27': 421,
#   'Total requested': 421},
#  {'Jurisdiction': 'Nevada',
#   'Allocation 2022-07-29 to onwards': 5360,
#   'Allocation 2022-06-28 to 2022-07-27': 1939,
#   'Total allocation': 7299,
#   'Total deployed as of 2022-07-27': 691,
#   'Total requested': 691},
#  {'Jurisdiction': 'New Hampshire',
#   'Allocation 2022-07-29 to onwards': 1140,
#   'Allocation 2022-06-28 to 2022-07-27': 327,
#   'Total allocation': 1467,
#   'Total deployed as of 2022-07-27': 327,
#   'Total requested': 327},
#  {'Jurisdiction': 'New Jersey',
#   'Allocation 2022-07-29 to onwards': 14520,
#   'Allocation 2022-06-28 to 2022-07-27': 5449,
#   'Total allocation': 19969,
#   'Total deployed as of 2022-07-27': 5509,
#   'Total requested': 5509},
#  {'Jurisdiction': 'New Mexico',
#   'Allocation 2022-07-29 to onwards': 2600,
#   'Allocation 2022-06-28 to 2022-07-27': 956,
#   'Total allocation': 3556,
#   'Total deployed as of 2022-07-27': 956,
#   'Total requested': 956},
#  {'Jurisdiction': 'New York -    New York City',
#   'Allocation 2022-07-29 to onwards': 80040,
#   'Allocation 2022-06-28 to 2022-07-27': 44604,
#   'Total allocation': 124644,
#   'Total deployed as of 2022-07-27': 45784,
#   'Total requested': 44604},
#  {'Jurisdiction': 'New York -    Other',
#   'Allocation 2022-07-29 to onwards': 29600,
#   'Allocation 2022-06-28 to 2022-07-27': 16426,
#   'Total allocation': 46026,
#   'Total deployed as of 2022-07-27': 16455,
#   'Total requested': 17635},
#  {'Jurisdiction': 'North    Carolina',
#   'Allocation 2022-07-29 to onwards': 13840,
#   'Allocation 2022-06-28 to 2022-07-27': 4548,
#   'Total allocation': 18388,
#   'Total deployed as of 2022-07-27': 4608,
#   'Total requested': 4608},
#  {'Jurisdiction': 'North Dakota',
#   'Allocation 2022-07-29 to onwards': 420,
#   'Allocation 2022-06-28 to 2022-07-27': 95,
#   'Total allocation': 515,
#   'Total deployed as of 2022-07-27': 95,
#   'Total requested': 95},
#  {'Jurisdiction': 'Ohio',
#   'Allocation 2022-07-29 to onwards': 13560,
#   'Allocation 2022-06-28 to 2022-07-27': 4249,
#   'Total allocation': 17809,
#   'Total deployed as of 2022-07-27': 4253,
#   'Total requested': 4253},
#  {'Jurisdiction': 'Oklahoma',
#   'Allocation 2022-07-29 to onwards': 4120,
#   'Allocation 2022-06-28 to 2022-07-27': 1435,
#   'Total allocation': 5555,
#   'Total deployed as of 2022-07-27': 336,
#   'Total requested': 336},
#  {'Jurisdiction': 'Oregon',
#   'Allocation 2022-07-29 to onwards': 8480,
#   'Allocation 2022-06-28 to 2022-07-27': 3428,
#   'Total allocation': 11908,
#   'Total deployed as of 2022-07-27': 3438,
#   'Total requested': 3438},
#  {'Jurisdiction': 'Pennsylvania    - Philadelphia',
#   'Allocation 2022-07-29 to onwards': 6020,
#   'Allocation 2022-06-28 to 2022-07-27': 2370,
#   'Total allocation': 8390,
#   'Total deployed as of 2022-07-27': 2370,
#   'Total requested': 2370},
#  {'Jurisdiction': 'Pennsylvania    - Other',
#   'Allocation 2022-07-29 to onwards': 12620,
#   'Allocation 2022-06-28 to 2022-07-27': 5219,
#   'Total allocation': 17839,
#   'Total deployed as of 2022-07-27': 5251,
#   'Total requested': 5249},
#  {'Jurisdiction': 'Rhode Island',
#   'Allocation 2022-07-29 to onwards': 2220,
#   'Allocation 2022-06-28 to 2022-07-27': 954,
#   'Total allocation': 3174,
#   'Total deployed as of 2022-07-27': 974,
#   'Total requested': 974},
#  {'Jurisdiction': 'South    Carolina',
#   'Allocation 2022-07-29 to onwards': 5220,
#   'Allocation 2022-06-28 to 2022-07-27': 1513,
#   'Total allocation': 6733,
#   'Total deployed as of 2022-07-27': 1547,
#   'Total requested': 1547},
#  {'Jurisdiction': 'South Dakota',
#   'Allocation 2022-07-29 to onwards': 360,
#   'Allocation 2022-06-28 to 2022-07-27': 151,
#   'Total allocation': 511,
#   'Total deployed as of 2022-07-27': 47,
#   'Total requested': 151},
#  {'Jurisdiction': 'Tennessee',
#   'Allocation 2022-07-29 to onwards': 8360,
#   'Allocation 2022-06-28 to 2022-07-27': 2380,
#   'Total allocation': 10740,
#   'Total deployed as of 2022-07-27': 2402,
#   'Total requested': 2402},
#  {'Jurisdiction': 'Texas -    Houston',
#   'Allocation 2022-07-29 to onwards': 16780,
#   'Allocation 2022-06-28 to 2022-07-27': 5324,
#   'Total allocation': 22104,
#   'Total deployed as of 2022-07-27': 5324,
#   'Total requested': 5324},
#  {'Jurisdiction': 'Texas - Other',
#   'Allocation 2022-07-29 to onwards': 41840,
#   'Allocation 2022-06-28 to 2022-07-27': 15440,
#   'Total allocation': 57280,
#   'Total deployed as of 2022-07-27': 15636,
#   'Total requested': 15636},
#  {'Jurisdiction': 'Utah',
#   'Allocation 2022-07-29 to onwards': 4080,
#   'Allocation 2022-06-28 to 2022-07-27': 2289,
#   'Total allocation': 6369,
#   'Total deployed as of 2022-07-27': 2309,
#   'Total requested': 2309},
#  {'Jurisdiction': 'Vermont',
#   'Allocation 2022-07-29 to onwards': 340,
#   'Allocation 2022-06-28 to 2022-07-27': 86,
#   'Total allocation': 426,
#   'Total deployed as of 2022-07-27': 86,
#   'Total requested': 86},
#  {'Jurisdiction': 'Virginia',
#   'Allocation 2022-07-29 to onwards': 15540,
#   'Allocation 2022-06-28 to 2022-07-27': 7113,
#   'Total allocation': 22653,
#   'Total deployed as of 2022-07-27': 7239,
#   'Total requested': 7239},
#  {'Jurisdiction': 'Washington',
#   'Allocation 2022-07-29 to onwards': 17280,
#   'Allocation 2022-06-28 to 2022-07-27': 7166,
#   'Total allocation': 24446,
#   'Total deployed as of 2022-07-27': 6890,
#   'Total requested': 6890},
#  {'Jurisdiction': 'West Virginia',
#   'Allocation 2022-07-29 to onwards': 1480,
#   'Allocation 2022-06-28 to 2022-07-27': 427,
#   'Total allocation': 1907,
#   'Total deployed as of 2022-07-27': 457,
#   'Total requested': 457},
#  {'Jurisdiction': 'Wisconsin',
#   'Allocation 2022-07-29 to onwards': 4500,
#   'Allocation 2022-06-28 to 2022-07-27': 1486,
#   'Total allocation': 5986,
#   'Total deployed as of 2022-07-27': 1354,
#   'Total requested': 1514},
#  {'Jurisdiction': 'Wyoming',
#   'Allocation 2022-07-29 to onwards': 240,
#   'Allocation 2022-06-28 to 2022-07-27': 61,
#   'Total allocation': 301,
#   'Total deployed as of 2022-07-27': 61,
#   'Total requested': 61},
#  {'Jurisdiction': '',
#   'Allocation 2022-07-29 to onwards': '',
#   'Allocation 2022-06-28 to 2022-07-27': '',
#   'Total allocation': '',
#   'Total deployed as of 2022-07-27': '',
#   'Total requested': ''},
#  {'Jurisdiction': 'Puerto Rico',
#   'Allocation 2022-07-29 to onwards': 3840,
#   'Allocation 2022-06-28 to 2022-07-27': 1227,
#   'Total allocation': 5067,
#   'Total deployed as of 2022-07-27': 1267,
#   'Total requested': 1267},
#  {'Jurisdiction': 'US Virgin    Islands',
#   'Allocation 2022-07-29 to onwards': 100,
#   'Allocation 2022-06-28 to 2022-07-27': 8,
#   'Total allocation': 108,
#   'Total deployed as of 2022-07-27': 100,
#   'Total requested': 100},
#  {'Jurisdiction': 'Guam',
#   'Allocation 2022-07-29 to onwards': 60,
#   'Allocation 2022-06-28 to 2022-07-27': 4,
#   'Total allocation': 64,
#   'Total deployed as of 2022-07-27': '-',
#   'Total requested': '-'},
#  {'Jurisdiction': 'Northern    Mariana Islands',
#   'Allocation 2022-07-29 to onwards': 20,
#   'Allocation 2022-06-28 to 2022-07-27': 1,
#   'Total allocation': 21,
#   'Total deployed as of 2022-07-27': '-',
#   'Total requested': '-'},
#  {'Jurisdiction': 'American    Samoa',
#   'Allocation 2022-07-29 to onwards': 20,
#   'Allocation 2022-06-28 to 2022-07-27': '-',
#   'Total allocation': 20,
#   'Total deployed as of 2022-07-27': '-',
#   'Total requested': '-'},
#  {'Jurisdiction': 'Tribal    entities',
#   'Allocation 2022-07-29 to onwards': 160,
#   'Allocation 2022-06-28 to 2022-07-27': 13,
#   'Total allocation': 173,
#   'Total deployed as of 2022-07-27': '-\u200b',
#   'Total requested': '-\u200b'}]

# %%
for i in range(1,32):
    print(i, ":")
    data = fetch_jynneos_table_near(2022, 7, i)
    print(data[:3])
# Out:
# 1 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 2 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 3 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 4 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 5 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 6 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 7 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 8 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 9 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 10 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 11 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 12 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 13 :
# [{'Jurisdiction': 'All', 'Total distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total distribution': 20}, {'Jurisdiction': 'Arizona', 'Total distribution': 118}]
# 14 :
# [{'Jurisdiction': 'All', 'Total distribution': 132074}, {'Jurisdiction': 'Alabama', 'Total distribution': 10}, {'Jurisdiction': 'Alaska', 'Total distribution': 102}]
# 15 :
# [{'Jurisdiction': 'All', 'Total distribution': 132074}, {'Jurisdiction': 'Alabama', 'Total distribution': 10}, {'Jurisdiction': 'Alaska', 'Total distribution': 102}]
# 16 :
# [{'Jurisdiction': 'All', 'Total distribution': 132074}, {'Jurisdiction': 'Alabama', 'Total distribution': 10}, {'Jurisdiction': 'Alaska', 'Total distribution': 102}]
# 17 :
# [{'Jurisdiction': 'All', 'Total distribution': 132074}, {'Jurisdiction': 'Alabama', 'Total distribution': 10}, {'Jurisdiction': 'Alaska', 'Total distribution': 102}]
# 18 :
# [{'Jurisdiction': 'All', 'Total distribution': 132074}, {'Jurisdiction': 'Alabama', 'Total distribution': 10}, {'Jurisdiction': 'Alaska', 'Total distribution': 102}]
# 19 :
# [{'Jurisdiction': 'All', 'Total distribution': 191372}, {'Jurisdiction': 'Alabama', 'Total distribution': 12}, {'Jurisdiction': 'Alaska', 'Total distribution': 102}]
# 20 :
# [{'Jurisdiction': 'All', 'Total distribution': 191372}, {'Jurisdiction': 'Alabama', 'Total distribution': 12}, {'Jurisdiction': 'Alaska', 'Total distribution': 102}]
# 21 :
# [{'Jurisdiction': 'All', 'Total distribution': 191372}, {'Jurisdiction': 'Alabama', 'Total distribution': 12}, {'Jurisdiction': 'Alaska', 'Total distribution': 102}]
# 22 :
# [{'Jurisdiction': 'All', 'Total allocation': 333218, 'Total requested': 321615, 'Total shipped': 310385}, {'Jurisdiction': 'Alabama', 'Total allocation': 1283, 'Total requested': '1,2\u200b83', 'Total shipped': 1282}, {'Jurisdiction': 'Alaska', 'Total allocation': 120, 'Total requested': 102, 'Total shipped': 102}]
# 23 :
# [{'Jurisdiction': 'All', 'Total allocation': 333218, 'Total requested': 321615, 'Total shipped': 310385}, {'Jurisdiction': 'Alabama', 'Total allocation': 1283, 'Total requested': '1,2\u200b83', 'Total shipped': 1282}, {'Jurisdiction': 'Alaska', 'Total allocation': 120, 'Total requested': 102, 'Total shipped': 102}]
# 24 :
# [{'Jurisdiction': 'All', 'Total allocation': 333218, 'Total requested': 321615, 'Total shipped': 310385}, {'Jurisdiction': 'Alabama', 'Total allocation': 1283, 'Total requested': '1,2\u200b83', 'Total shipped': 1282}, {'Jurisdiction': 'Alaska', 'Total allocation': 120, 'Total requested': 102, 'Total shipped': 102}]
# 25 :
# [{'Jurisdiction': 'All', 'Total allocation': 333218, 'Total requested': 321615, 'Total shipped': 310385}, {'Jurisdiction': 'Alabama', 'Total allocation': 1283, 'Total requested': '1,2\u200b83', 'Total shipped': 1282}, {'Jurisdiction': 'Alaska', 'Total allocation': 120, 'Total requested': 102, 'Total shipped': 102}]
# 26 :
# [{'Jurisdiction': 'All', 'Total allocation': 333218, 'Total requested': 321615, 'Total shipped': 310385}, {'Jurisdiction': 'Alabama', 'Total allocation': 1283, 'Total requested': '1,2\u200b83', 'Total shipped': 1282}, {'Jurisdiction': 'Alaska', 'Total allocation': 120, 'Total requested': 102, 'Total shipped': 102}]
# 27 :
# [{'Jurisdiction': 'All', 'Total allocation': 333218, 'Total requested': 321615, 'Total shipped': 310385}, {'Jurisdiction': 'Alabama', 'Total allocation': 1283, 'Total requested': '1,2\u200b83', 'Total shipped': 1282}, {'Jurisdiction': 'Alaska', 'Total allocation': 120, 'Total requested': 102, 'Total shipped': 102}]
# 28 :
# [{'Jurisdiction': 'All', 'Total allocation': 333218, 'Total requested': 321615, 'Total shipped': 310385}, {'Jurisdiction': 'Alabama', 'Total allocation': 1283, 'Total requested': '1,2\u200b83', 'Total shipped': 1282}, {'Jurisdiction': 'Alaska', 'Total allocation': 120, 'Total requested': 102, 'Total shipped': 102}]
# 29 :
# [{'Jurisdiction': 'All', 'Allocation 2022-07-29 to onwards': '736,620*\u200b', 'Allocation 2022-06-28 to 2022-07-27': 333218, 'Total allocation': 1069838, 'Total deployed as of 2022-07-27': 336710, 'Total requested': 337016}, {'Jurisdiction': 'Alabama', 'Allocation 2022-07-29 to onwards': 4640, 'Allocation 2022-06-28 to 2022-07-27': 1283, 'Total allocation': 5923, 'Total deployed as of 2022-07-27': 1283, 'Total requested': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-07-29 to onwards': 480, 'Allocation 2022-06-28 to 2022-07-27': 120, 'Total allocation': 600, 'Total deployed as of 2022-07-27': 102, 'Total requested': 102}]
# 30 :
# [{'Jurisdiction': 'All', 'Allocation 2022-07-29 to onwards': '736,620*\u200b', 'Allocation 2022-06-28 to 2022-07-27': 333218, 'Total allocation': 1069838, 'Total deployed as of 2022-07-27': 336710, 'Total requested': 337016}, {'Jurisdiction': 'Alabama', 'Allocation 2022-07-29 to onwards': 4640, 'Allocation 2022-06-28 to 2022-07-27': 1283, 'Total allocation': 5923, 'Total deployed as of 2022-07-27': 1283, 'Total requested': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-07-29 to onwards': 480, 'Allocation 2022-06-28 to 2022-07-27': 120, 'Total allocation': 600, 'Total deployed as of 2022-07-27': 102, 'Total requested': 102}]
# 31 :
# [{'Jurisdiction': 'All', 'Allocation 2022-07-29 to onwards': '736,620*\u200b', 'Allocation 2022-06-28 to 2022-07-27': 333218, 'Total allocation': 1069838, 'Total deployed as of 2022-07-27': 336710, 'Total requested': 337016}, {'Jurisdiction': 'Alabama', 'Allocation 2022-07-29 to onwards': 4640, 'Allocation 2022-06-28 to 2022-07-27': 1283, 'Total allocation': 5923, 'Total deployed as of 2022-07-27': 1283, 'Total requested': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-07-29 to onwards': 480, 'Allocation 2022-06-28 to 2022-07-27': 120, 'Total allocation': 600, 'Total deployed as of 2022-07-27': 102, 'Total requested': 102}]

# %%
fields = list()
for i in range(1,32):
    print(i, ":")
    data = fetch_jynneos_table_near(2022, 7, i)
    keys = list(data[0].keys())
    fields += keys
    print(fetch_jynneos_table_near(2022, 7, i)[:3])
print(fields)
# Out:
# 1 :
# [{'Jurisdiction': 'All Jurisdictions (patient courses)', 'Total Distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution': 118}]
# 2 :
# [{'Jurisdiction': 'All Jurisdictions (patient courses)', 'Total Distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution': 118}]
# 3 :
# [{'Jurisdiction': 'All Jurisdictions (patient courses)', 'Total Distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution': 118}]
# 4 :
# [{'Jurisdiction': 'All Jurisdictions (patient courses)', 'Total Distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution': 118}]
# 5 :
# [{'Jurisdiction': 'All Jurisdictions (patient courses)', 'Total Distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution': 118}]
# 6 :
# [{'Jurisdiction': 'All Jurisdictions (patient courses)', 'Total Distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution': 118}]
# 7 :
# [{'Jurisdiction': 'All Jurisdictions (patient courses)', 'Total Distribution': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution': 118}]
# 8 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution (Doses)\u200b': 118}]
# 9 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution (Doses)\u200b': 118}]
# 10 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution (Doses)\u200b': 118}]
# 11 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution (Doses)\u200b': 118}]
# 12 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution (Doses)\u200b': 118}]
# 13 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 41520}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 20}, {'Jurisdiction': 'Arizona', 'Total Distribution (Doses)\u200b': 118}]
# 14 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 132074}, {'Jurisdiction': 'Alabama', 'Total Distribution (Doses)\u200b': 10}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 102}]
# 15 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 132074}, {'Jurisdiction': 'Alabama', 'Total Distribution (Doses)\u200b': 10}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 102}]
# 16 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 132074}, {'Jurisdiction': 'Alabama', 'Total Distribution (Doses)\u200b': 10}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 102}]
# 17 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 132074}, {'Jurisdiction': 'Alabama', 'Total Distribution (Doses)\u200b': 10}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 102}]
# 18 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 132074}, {'Jurisdiction': 'Alabama', 'Total Distribution (Doses)\u200b': 10}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 102}]
# 19 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 191372}, {'Jurisdiction': 'Alabama', 'Total Distribution (Doses)\u200b': 12}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 102}]
# 20 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 191372}, {'Jurisdiction': 'Alabama', 'Total Distribution (Doses)\u200b': 12}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 102}]
# 21 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Distribution (Doses)\u200b': 191372}, {'Jurisdiction': 'Alabama', 'Total Distribution (Doses)\u200b': 12}, {'Jurisdiction': 'Alaska', 'Total Distribution (Doses)\u200b': 102}]
# 22 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Allocation': 333218, 'Total Requested': 321615, 'Total Shipped\xa0(Doses)\u200b': 310385}, {'Jurisdiction': 'Alabama', 'Total Allocation': 1283, 'Total Requested': '1,2\u200b83', 'Total Shipped\xa0(Doses)\u200b': 1282}, {'Jurisdiction': 'Alaska', 'Total Allocation': 120, 'Total Requested': 102, 'Total Shipped\xa0(Doses)\u200b': 102}]
# 23 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Allocation': 333218, 'Total Requested': 321615, 'Total Shipped\xa0(Doses)\u200b': 310385}, {'Jurisdiction': 'Alabama', 'Total Allocation': 1283, 'Total Requested': '1,2\u200b83', 'Total Shipped\xa0(Doses)\u200b': 1282}, {'Jurisdiction': 'Alaska', 'Total Allocation': 120, 'Total Requested': 102, 'Total Shipped\xa0(Doses)\u200b': 102}]
# 24 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Allocation': 333218, 'Total Requested': 321615, 'Total Shipped\xa0(Doses)\u200b': 310385}, {'Jurisdiction': 'Alabama', 'Total Allocation': 1283, 'Total Requested': '1,2\u200b83', 'Total Shipped\xa0(Doses)\u200b': 1282}, {'Jurisdiction': 'Alaska', 'Total Allocation': 120, 'Total Requested': 102, 'Total Shipped\xa0(Doses)\u200b': 102}]
# 25 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Allocation': 333218, 'Total Requested': 321615, 'Total Shipped\xa0(Doses)\u200b': 310385}, {'Jurisdiction': 'Alabama', 'Total Allocation': 1283, 'Total Requested': '1,2\u200b83', 'Total Shipped\xa0(Doses)\u200b': 1282}, {'Jurisdiction': 'Alaska', 'Total Allocation': 120, 'Total Requested': 102, 'Total Shipped\xa0(Doses)\u200b': 102}]
# 26 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Allocation': 333218, 'Total Requested': 321615, 'Total Shipped\xa0(Doses)\u200b': 310385}, {'Jurisdiction': 'Alabama', 'Total Allocation': 1283, 'Total Requested': '1,2\u200b83', 'Total Shipped\xa0(Doses)\u200b': 1282}, {'Jurisdiction': 'Alaska', 'Total Allocation': 120, 'Total Requested': 102, 'Total Shipped\xa0(Doses)\u200b': 102}]
# 27 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Allocation': 333218, 'Total Requested': 321615, 'Total Shipped\xa0(Doses)\u200b': 310385}, {'Jurisdiction': 'Alabama', 'Total Allocation': 1283, 'Total Requested': '1,2\u200b83', 'Total Shipped\xa0(Doses)\u200b': 1282}, {'Jurisdiction': 'Alaska', 'Total Allocation': 120, 'Total Requested': 102, 'Total Shipped\xa0(Doses)\u200b': 102}]
# 28 :
# [{'Jurisdiction': 'All Jurisdictions', 'Total Allocation': 333218, 'Total Requested': 321615, 'Total Shipped\xa0(Doses)\u200b': 310385}, {'Jurisdiction': 'Alabama', 'Total Allocation': 1283, 'Total Requested': '1,2\u200b83', 'Total Shipped\xa0(Doses)\u200b': 1282}, {'Jurisdiction': 'Alaska', 'Total Allocation': 120, 'Total Requested': 102, 'Total Shipped\xa0(Doses)\u200b': 102}]
# 29 :
# [{'Jurisdiction': 'All    Jurisdictions', 'AllocationJune 28-July 27': 333218, 'Allocation July 29': '736,620*\u200b', 'Total    Allocation': 1069838, 'Total Requested': 337016, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 336710}, {'Jurisdiction': 'Alabama', 'AllocationJune 28-July 27': 1283, 'Allocation July 29': 4640, 'Total    Allocation': 5923, 'Total Requested': 1283, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 1283}, {'Jurisdiction': 'Alaska', 'AllocationJune 28-July 27': 120, 'Allocation July 29': 480, 'Total    Allocation': 600, 'Total Requested': 102, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 102}]
# 30 :
# [{'Jurisdiction': 'All    Jurisdictions', 'AllocationJune 28-July 27': 333218, 'Allocation July 29': '736,620*\u200b', 'Total    Allocation': 1069838, 'Total Requested': 337016, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 336710}, {'Jurisdiction': 'Alabama', 'AllocationJune 28-July 27': 1283, 'Allocation July 29': 4640, 'Total    Allocation': 5923, 'Total Requested': 1283, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 1283}, {'Jurisdiction': 'Alaska', 'AllocationJune 28-July 27': 120, 'Allocation July 29': 480, 'Total    Allocation': 600, 'Total Requested': 102, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 102}]
# 31 :
# [{'Jurisdiction': 'All    Jurisdictions', 'AllocationJune 28-July 27': 333218, 'Allocation July 29': '736,620*\u200b', 'Total    Allocation': 1069838, 'Total Requested': 337016, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 336710}, {'Jurisdiction': 'Alabama', 'AllocationJune 28-July 27': 1283, 'Allocation July 29': 4640, 'Total    Allocation': 5923, 'Total Requested': 1283, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 1283}, {'Jurisdiction': 'Alaska', 'AllocationJune 28-July 27': 120, 'Allocation July 29': 480, 'Total    Allocation': 600, 'Total Requested': 102, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 102}]
# ['Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b', 'Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b', 'Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b']

# %%
for i in range(1,32):
    print(i, ":")
    data = fetch_jynneos_table_near(2022, 8, i)
    keys = list(data[0].keys())
    fields += keys
    print(data[:3])
print(fields)
# Out:
# 1 :
# [{'Jurisdiction': 'All    Jurisdictions', 'AllocationJune 28-July 27': 333218, 'Allocation July 29': '736,620*\u200b', 'Total    Allocation': 1069838, 'Total Requested': 337016, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 336710}, {'Jurisdiction': 'Alabama', 'AllocationJune 28-July 27': 1283, 'Allocation July 29': 4640, 'Total    Allocation': 5923, 'Total Requested': 1283, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 1283}, {'Jurisdiction': 'Alaska', 'AllocationJune 28-July 27': 120, 'Allocation July 29': 480, 'Total    Allocation': 600, 'Total Requested': 102, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 102}]
# 2 :
# [{'Jurisdiction': 'All    Jurisdictions', 'AllocationJune 28-July 27': 333218, 'Allocation July 29': '736,620*\u200b', 'Total    Allocation': 1069838, 'Total Requested as of July 27 at 8AM': 337016, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 336710}, {'Jurisdiction': 'Alabama', 'AllocationJune 28-July 27': 1283, 'Allocation July 29': 4640, 'Total    Allocation': 5923, 'Total Requested as of July 27 at 8AM': 1283, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 1283}, {'Jurisdiction': 'Alaska', 'AllocationJune 28-July 27': 120, 'Allocation July 29': 480, 'Total    Allocation': 600, 'Total Requested as of July 27 at 8AM': 102, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 102}]
# 3 :
# [{'Jurisdiction': 'All    Jurisdictions', 'AllocationJune 28-July 27': 333218, 'Allocation July 29': '736,620*\u200b', 'Total    Allocation': 1069838, 'Total Requested as of July 27 at 8AM': 337016, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 336710}, {'Jurisdiction': 'Alabama', 'AllocationJune 28-July 27': 1283, 'Allocation July 29': 4640, 'Total    Allocation': 5923, 'Total Requested as of July 27 at 8AM': 1283, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 1283}, {'Jurisdiction': 'Alaska', 'AllocationJune 28-July 27': 120, 'Allocation July 29': 480, 'Total    Allocation': 600, 'Total Requested as of July 27 at 8AM': 102, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 102}]
# 4 :
# [{'Jurisdiction': 'All    Jurisdictions', 'AllocationJune 28-July 27': 333218, 'Allocation July 29': '736,620*\u200b', 'Total    Allocation': 1069838, 'Total Requested as of July 27 at 8AM': 337016, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 336710}, {'Jurisdiction': 'Alabama', 'AllocationJune 28-July 27': 1283, 'Allocation July 29': 4640, 'Total    Allocation': 5923, 'Total Requested as of July 27 at 8AM': 1283, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 1283}, {'Jurisdiction': 'Alaska', 'AllocationJune 28-July 27': 120, 'Allocation July 29': 480, 'Total    Allocation': 600, 'Total Requested as of July 27 at 8AM': 102, 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b': 102}]
# 5 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736620, 'Total Allocation': 1069840, 'Total Requestedas of Aug 03 2022, 12pm': 580733, 'Total Shippedas of Aug 03 2022, 12pm': 580733}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 03 2022, 12pm': 1283, 'Total Shippedas of Aug 03 2022, 12pm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 03 2022, 12pm': 340, 'Total Shippedas of Aug 03 2022, 12pm': 340}]
# 6 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736620, 'Total Allocation': 1069840, 'Total Requestedas of Aug 03 2022, 12pm': 580733, 'Total Shippedas of Aug 03 2022, 12pm': 580733}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 03 2022, 12pm': 1283, 'Total Shippedas of Aug 03 2022, 12pm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 03 2022, 12pm': 340, 'Total Shippedas of Aug 03 2022, 12pm': 340}]
# 7 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736620, 'Total Allocation': 1069840, 'Total Requestedas of Aug 03 2022, 12pm': 580733, 'Total Shippedas of Aug 03 2022, 12pm': 580733}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 03 2022, 12pm': 1283, 'Total Shippedas of Aug 03 2022, 12pm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 03 2022, 12pm': 340, 'Total Shippedas of Aug 03 2022, 12pm': 340}]
# 8 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736620, 'Total Allocation': 1069840, 'Total Requestedas of Aug 03 2022, 12pm': 580733, 'Total Shippedas of Aug 03 2022, 12pm': 580733}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 03 2022, 12pm': 1283, 'Total Shippedas of Aug 03 2022, 12pm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 03 2022, 12pm': 340, 'Total Shippedas of Aug 03 2022, 12pm': 340}]
# 9 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736620, 'Total Allocation': 1069840, 'Total Requestedas of Aug 08 2022, 12pm': 617693, 'Total Shippedas of Aug 08 2022, 12pm': 617693}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 08 2022, 12pm': 1283, 'Total Shippedas of Aug 08 2022, 12pm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 08 2022, 12pm': 340, 'Total Shippedas of Aug 08 2022, 12pm': 340}]
# 10 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736620, 'Total Allocation': 1069840, 'Total Requestedas of Aug 08 2022, 12pm': 617693, 'Total Shippedas of Aug 08 2022, 12pm': 617693}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 08 2022, 12pm': 1283, 'Total Shippedas of Aug 08 2022, 12pm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 08 2022, 12pm': 340, 'Total Shippedas of Aug 08 2022, 12pm': 340}]
# 11 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 10 2022, 12pm': 634213, 'Total Shippedas of Aug 10 2022, 12pm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 10 2022, 12pm': 1283, 'Total Shippedas of Aug 10 2022, 12pm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 10 2022, 12pm': 340, 'Total Shippedas of Aug 10 2022, 12pm': 340}]
# 12 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 10 2022, 12pm': 634213, 'Total Shippedas of Aug 10 2022, 12pm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 10 2022, 12pm': 1283, 'Total Shippedas of Aug 10 2022, 12pm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 10 2022, 12pm': 340, 'Total Shippedas of Aug 10 2022, 12pm': 340}]
# 13 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 14 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 15 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 16 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 17 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 18 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 19 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 20 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 21 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 22 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 23 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 24 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 25 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 26 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 27 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 28 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 29 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 30 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# 31 :
# [{'Jurisdiction': 'All Jurisdictions', 'Allocation 2022-06-29 To 2022-07-08': 56001, 'Allocation 2022-07-08 To 2022-07-15': 146217, 'Allocation 2022-07-16 To 2022-07-29': 131002, 'Allocation 2022-07-29 To Onwards': 736639, 'Total Allocation': 1069859, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 634213, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 634213}, {'Jurisdiction': 'Alabama', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 768, 'Allocation 2022-07-16 To 2022-07-29': 515, 'Allocation 2022-07-29 To Onwards': 4640, 'Total Allocation': 5923, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 1283, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 1283}, {'Jurisdiction': 'Alaska', 'Allocation 2022-06-29 To 2022-07-08': 0, 'Allocation 2022-07-08 To 2022-07-15': 82, 'Allocation 2022-07-16 To 2022-07-29': 38, 'Allocation 2022-07-29 To Onwards': 480, 'Total Allocation': 600, 'Total Requestedas of Aug 12\u200b 2022, 12pm': 340, 'Total Shippedas of Aug 12 2022, 12\u200bpm': 340}]
# ['Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Distribution (Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'Total Allocation', 'Total Requested', 'Total Shipped\xa0(Doses)\u200b', 'Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b', 'Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b', 'Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b', 'Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b', 'Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested as of July 27 at 8AM', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b', 'Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested as of July 27 at 8AM', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b', 'Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested as of July 27 at 8AM', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b', 'Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 03 2022, 12pm', 'Total Shippedas of Aug 03 2022, 12pm', 'Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 03 2022, 12pm', 'Total Shippedas of Aug 03 2022, 12pm', 'Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 03 2022, 12pm', 'Total Shippedas of Aug 03 2022, 12pm', 'Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 03 2022, 12pm', 'Total Shippedas of Aug 03 2022, 12pm', 'Jurisdiction', 'Allocation 2022-06-29 ...

# %%
singl_fields = set(fields)

# %%
singl_fields
# Out:
# {'Allocation 2022-06-29 To 2022-07-08',
#  'Allocation 2022-07-08 To 2022-07-15',
#  'Allocation 2022-07-16 To 2022-07-29',
#  'Allocation 2022-07-29 To Onwards',
#  'Allocation July 29',
#  'AllocationJune 28-July 27',
#  'Jurisdiction',
#  'Total    Allocation',
#  'Total Allocation',
#  'Total Distribution',
#  'Total Distribution (Doses)\u200b',
#  'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b',
#  'Total Requested',
#  'Total Requested as of July 27 at 8AM',
#  'Total Requestedas of Aug 03 2022, 12pm',
#  'Total Requestedas of Aug 08 2022, 12pm',
#  'Total Requestedas of Aug 10 2022, 12pm',
#  'Total Requestedas of Aug 12\u200b 2022, 12pm',
#  'Total Shippedas of Aug 03 2022, 12pm',
#  'Total Shippedas of Aug 08 2022, 12pm',
#  'Total Shippedas of Aug 10 2022, 12pm',
#  'Total Shippedas of Aug 12 2022, 12\u200bpm',
#  'Total Shipped\xa0(Doses)\u200b'}

# %%
for i in range(1,32):
    print(i, ":")
    print(fetch_jynneos_table_near(2022, 8, i)[:3])
# Out:
# 1 :
# [['Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b'], ['All    Jurisdictions', '333,218', '736,620*\u200b', '1,069,838', '337,016', '336,710'], ['Alabama', '1,283', '4,640', '5,923', '1,283', '1,283']]
# 2 :
# [['Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested as of July 27 at 8AM', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b'], ['All    Jurisdictions', '333,218', '736,620*\u200b', '1,069,838', '337,016', '336,710'], ['Alabama', '1,283', '4,640', '5,923', '1,283', '1,283']]
# 3 :
# [['Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested as of July 27 at 8AM', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b'], ['All    Jurisdictions', '333,218', '736,620*\u200b', '1,069,838', '337,016', '336,710'], ['Alabama', '1,283', '4,640', '5,923', '1,283', '1,283']]
# 4 :
# [['Jurisdiction', 'AllocationJune 28-July 27', 'Allocation July 29', 'Total    Allocation', 'Total Requested as of July 27 at 8AM', 'Total Doses    Shipped or Deployedas of July 27, 8AM\u200b'], ['All    Jurisdictions', '333,218', '736,620*\u200b', '1,069,838', '337,016', '336,710'], ['Alabama', '1,283', '4,640', '5,923', '1,283', '1,283']]
# 5 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 03 2022, 12pm', 'Total Shippedas of Aug 03 2022, 12pm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,620', '1,069,840', '580,733', '580,733'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 6 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 03 2022, 12pm', 'Total Shippedas of Aug 03 2022, 12pm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,620', '1,069,840', '580,733', '580,733'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 7 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 03 2022, 12pm', 'Total Shippedas of Aug 03 2022, 12pm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,620', '1,069,840', '580,733', '580,733'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 8 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 03 2022, 12pm', 'Total Shippedas of Aug 03 2022, 12pm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,620', '1,069,840', '580,733', '580,733'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 9 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 08 2022, 12pm', 'Total Shippedas of Aug 08 2022, 12pm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,620', '1,069,840', '617,693', '617,693'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 10 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 08 2022, 12pm', 'Total Shippedas of Aug 08 2022, 12pm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,620', '1,069,840', '617,693', '617,693'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 11 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 10 2022, 12pm', 'Total Shippedas of Aug 10 2022, 12pm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 12 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 10 2022, 12pm', 'Total Shippedas of Aug 10 2022, 12pm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 13 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 14 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 15 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 16 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 17 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 18 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 19 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 20 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 21 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 22 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 23 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 24 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 25 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 26 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 27 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 28 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 29 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 30 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]
# 31 :
# [['Jurisdiction', 'Allocation 2022-06-29 To 2022-07-08', 'Allocation 2022-07-08 To 2022-07-15', 'Allocation 2022-07-16 To 2022-07-29', 'Allocation 2022-07-29 To Onwards', 'Total Allocation', 'Total Requestedas of Aug 12\u200b 2022, 12pm', 'Total Shippedas of Aug 12 2022, 12\u200bpm'], ['All Jurisdictions', '56,001', '146,217', '131,002', '736,639', '1,069,859', '634,213', '634,213'], ['Alabama', '0', '768', '515', '4,640', '5,923', '1,283', '1,283']]

# %%
open("test.csv","w").write(html2csv.Converter().convert(s.find("div", {"class": "table-responsive"}).find("table").prettify())[0][0])
# Out:
# 713

# %%
Converter().convert_to_list(s.find("div", {"class": "table-responsive"}).find("table").prettify())
# Out:
# [[['Jurisdiction', 'Total Distribution'],
#   ['All Jurisdictions (patient courses)', '41,520'],
#   ['Alaska', '20'],
#   ['Arizona', '118'],
#   ['California', '12,156'],
#   ['Chicago', '5,409'],
#   ['Colorado', '1,340'],
#   ['Connecticut', '10'],
#   ['Delaware', '16'],
#   ['District of Columbia', '1,706'],
#   ['Florida', '503'],
#   ['Georgia', '238'],
#   ['Hawaii', '557'],
#   ['Illinois', '126'],
#   ['Indiana', '520'],
#   ['Iowa', '26'],
#   ['Kentucky', '70'],
#   ['Los Angeles', '7,346'],
#   ['Louisiana', '20'],
#   ['Maine', '40'],
#   ['Maryland', '158'],
#   ['Massachusetts', '2,204'],
#   ['Michigan', '24'],
#   ['Minnesota', '40'],
#   ['Mississippi', '10'],
#   ['Missouri', '4'],
#   ['Nebraska', '50'],
#   ['Nevada', '4'],
#   ['New    Jersey', '300'],
#   ['New York', '31'],
#   ['New    York City', '7,169'],
#   ['North Carolina', '60'],
#   ['Ohio', '4'],
#   ['Oklahoma', '36'],
#   ['Oregon', '219'],
#   ['Pennsylvania', '98'],
#   ['Puerto    Rico', '40'],
#   ['Rhode Island', '20'],
#   ['South    Carolina', '34'],
#   ['Utah', '20'],
#   ['Texas', '166'],
#   ['Virginia', '512'],
#   ['Washington', '68'],
#   ['Wisconsin', '28']]]

# %%
import csv
import io

import bs4


def detect_engine():
    try:
        import lxml
    except ImportError:
        engine = 'html.parser'
    else:
        engine = 'lxml'
    return engine


class Converter:

    def __init__(self, **kwargs):
        engine = kwargs.get('engine')
        if engine is None:
            self.engine = detect_engine()
        else:
            self.engine = engine
        self.params = kwargs

    def convert_to_list(self, html_doc):
        soup = bs4.BeautifulSoup(html_doc, self.engine)
        tables = []
        for table_element in soup.find_all('table'):
            table = []
            for tr in table_element.find_all('tr'):
                row = [''.join(cell.stripped_strings)
                       for cell in tr.find_all(['td', 'th'])]
                table.append(row)
            tables.append(table)
        return tables

    def convert_to_csv(self, html_doc):
        tables = self.convert_to_list(html_doc)
        output = []
        for table_num, table in enumerate(tables):
            csv_string = io.StringIO()
            csv_writer = csv.writer(csv_string)
            for row in table:
                csv_writer.writerow(row)
            table_attrs = dict(num=table_num)
            output.append((csv_string.getvalue(), table_attrs))
        return output

    def convert(self, html_doc):
        return self.convert_to_csv(html_doc)
